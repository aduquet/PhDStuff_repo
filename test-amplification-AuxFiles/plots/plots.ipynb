# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
withstate = pd.read_csv('randoop.csv')
withOutstate = pd.read_csv('randoop_withoutChecks.csv')

# %%
withstate['test limit per class (7 classes)'].value_counts()
# Out:
# 2      10
# 4      10
# 8      10
# 16     10
# 32     10
# 64     10
# 128    10
# 256    10
# 512    10
# Name: test limit per class (7 classes), dtype: int64

# %%
withstate
# Out:
#           seed  test limit per class (7 classes) statecheck  \
# 0     54676380                                 2        yes
# 1    101322511                                 2        yes
# 2    379375655                                 2        yes
# 3    939145594                                 2        yes
# 4   1082618794                                 2        yes
# ..         ...                               ...        ...
# 85  1191369007                               512        yes
# 86  1256357748                               512        yes
# 87  1264048269                               512        yes
# 88  1321793073                               512        yes
# 89  2070236138                               512        yes
#
#     generated mutations  killed mutation score  uncovered mutants  \
# 0                   498      67            13%                381
# 1                   498     100            20%                347
# 2                   498      62            12%                399
# 3                   498      80            16%                370
# 4                   498      58            12%                406
# ..                  ...     ...            ...                ...
# 85                  498     266            53%                161
# 86                  498     248            50%                184
# 87                  498     263            53%                176
# 88                  498     265            53%                148
# 89                  498     262            53%                158
#
#    test strength (mutation score of covered mutants)
# 0                                                57%
# 1                                                66%
# 2                                                63%
# 3                                                63%
# 4                                                63%
# ..                                               ...
# 85                                               79%
# 86                                               79%
# 87                                               82%
# 88                                               76%
# 89                                               77%
#
# [90 rows x 8 columns]

# %%
withstate
